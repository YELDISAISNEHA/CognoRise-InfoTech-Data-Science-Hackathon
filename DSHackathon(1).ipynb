# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\SAI SNEHA\Documents\B191333\Hackathon\train.csv")
df
# Out:
#          Roll no test preparation   gender parental level of education  \
# 0      EXA000001              none    male                some college
# 1      EXA000002              none    male             master's degree
# 2      EXA000003              none    male             master's degree
# 3      EXA000004              none  female                some college
# 4      EXA000005              none  female                 high school
# ...          ...               ...     ...                         ...
# 31994  EXA031995              none    male            some high school
# 31995  EXA031996              none  female                 high school
# 31996  EXA031997              none    male           bachelor's degree
# 31997  EXA031998              none    male          associate's degree
# 31998  EXA031999              none    male            some high school
#
#               lunch    Section  practical score  viva score  exam score
# ...

# %%
df1=pd.read_csv(r"C:\Users\SAI SNEHA\Documents\B191333\Hackathon\test.csv")
df1
# Out:
#      Roll no test preparation   gender parental level of education  \
# 0   EXA32000              none    male          associate's degree
# 1   EXA32001         completed    male            some high school
# 2   EXA32002              none    male            some high school
# 3   EXA32003         completed    male            some high school
# 4   EXA32004              none  female           bachelor's degree
# ..       ...               ...     ...                         ...
# 95  EXA32095              none    male           bachelor's degree
# 96  EXA32096         completed    male          associate's degree
# 97  EXA32097              none    male                some college
# 98  EXA32098         completed    male          associate's degree
# 99  EXA32099              none    male                 high school
#
#            lunch    Section  practical score  viva score
# 0       standard  Section C               74          89
# ...

# %%
train=df
test=df1

# %%
train=train.drop('Roll no',axis='columns')
test=test.drop('Roll no',axis='columns')

# %%
train=train.rename(columns={'test preparation':'testPreparation','parental level of education':'parental_level_of_education','practical score':'practical_score','viva score':'viva_score','exam score':'exam_score'})
test=test.rename(columns={'test preparation':'testPreparation','parental level of education':'parental_level_of_education','practical score':'practical_score','viva score':'viva_score'})

# %%
train
# Out:
#       test preparation   gender parental_level_of_education         lunch  \
# 0                  none    male                some college      standard
# 1                  none    male             master's degree  free/reduced
# 2                  none    male             master's degree  free/reduced
# 3                  none  female                some college  free/reduced
# 4                  none  female                 high school      standard
# ...                 ...     ...                         ...           ...
# 31994              none    male            some high school  free/reduced
# 31995              none  female                 high school      standard
# 31996              none    male           bachelor's degree  free/reduced
# 31997              none    male          associate's degree      standard
# 31998              none    male            some high school      standard
#
#          Section  practical_score  viva_score  exam_score
# ...

# %%
test
# Out:
#    test preparation   gender parental_level_of_education         lunch  \
# 0               none    male          associate's degree      standard
# 1          completed    male            some high school      standard
# 2               none    male            some high school      standard
# 3          completed    male            some high school      standard
# 4               none  female           bachelor's degree      standard
# ..               ...     ...                         ...           ...
# 95              none    male           bachelor's degree      standard
# 96         completed    male          associate's degree  free/reduced
# 97              none    male                some college      standard
# 98         completed    male          associate's degree      standard
# 99              none    male                 high school      standard
#
#       Section  practical_score  viva_score
# 0   Section C               74          89
# ...

# %%
X_train=train.drop('exam_score',axis='columns')
y_train=train['exam_score']
X_train,y_train
# Out:
# (      test preparation   gender parental_level_of_education         lunch  \
#  0                  none    male                some college      standard
#  1                  none    male             master's degree  free/reduced
#  2                  none    male             master's degree  free/reduced
#  3                  none  female                some college  free/reduced
#  4                  none  female                 high school      standard
#  ...                 ...     ...                         ...           ...
#  31994              none    male            some high school  free/reduced
#  31995              none  female                 high school      standard
#  31996              none    male           bachelor's degree  free/reduced
#  31997              none    male          associate's degree      standard
#  31998              none    male            some high school      standard
#
#           Section  practical_score  viva_score
# ...

# %%
train.columns
# Out:
# Index(['test preparation ', 'gender', 'parental_level_of_education', 'lunch',
#        'Section', 'practical_score', 'viva_score', 'exam_score'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_test=LabelEncoder()
le_gend=LabelEncoder()
le_parental=LabelEncoder()
le_lunch=LabelEncoder()
le_sec=LabelEncoder()

# %%
X_train['test preparation ']=le_test.fit_transform(X_train['test preparation '])
X_train['gender']=le_gend.fit_transform(X_train['gender'])
X_train['parental_level_of_education']=le_gend.fit_transform(X_train['parental_level_of_education'])
X_train['lunch']=le_gend.fit_transform(X_train['lunch'])
X_train['Section']=le_gend.fit_transform(X_train['Section'])

# %%
test['test preparation ']=le_test.fit_transform(test['test preparation '])
test['gender']=le_gend.fit_transform(test['gender'])
test['parental_level_of_education']=le_gend.fit_transform(test['parental_level_of_education'])
test['lunch']=le_gend.fit_transform(test['lunch'])
test['Section']=le_gend.fit_transform(test['Section'])

# %%
X_train
# Out:
#        test preparation   gender  parental_level_of_education  lunch  Section  \
# 0                      1       1                            4      1        0
# 1                      1       1                            3      0        2
# 2                      1       1                            3      0        4
# 3                      1       0                            4      0        2
# 4                      1       0                            2      1        2
# ...                  ...     ...                          ...    ...      ...
# 31994                  1       1                            5      0        4
# 31995                  1       0                            2      1        1
# 31996                  1       1                            1      0        1
# 31997                  1       1                            0      1        3
# 31998                  1       1                            5      1        2
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(test)

# %%
y_pred
# Out:
# array([70.91      , 70.825     , 55.74      , 72.51083333, 65.11666667,
#        65.81      , 70.33      , 71.33083333, 73.27      , 66.87      ,
#        69.59      , 77.33      , 80.91      , 71.21416667, 66.854     ,
#        79.27      , 63.47      , 65.85533333, 69.07      , 70.26183333,
#        69.2       , 69.56      , 75.225     , 65.85      , 78.17666667,
#        72.84      , 68.43730952, 67.30333333, 71.61333333, 70.95      ,
#        67.29      , 76.31      , 65.73      , 70.22      , 70.245     ,
#        62.13166667, 52.95666667, 74.2       , 64.9       , 52.75      ,
#        73.67      , 68.35      , 67.00833333, 63.59      , 72.835     ,
#        76.55938095, 65.64      , 71.0725    , 76.2       , 61.88      ,
#        61.53566667, 72.33      , 81.26      , 72.905     , 66.17      ,
#        68.98      , 67.06      , 67.7335    , 65.8       , 70.88666667,
#        64.99      , 61.1       , 68.88      , 75.76733333, 66.824     ,
# ...

# %%
model.score(test,y_pred)
# Out:
# 1.0

# %% [markdown]
# Accuracy is 1

# %%
new = pd.DataFrame({'Roll No': df1['Roll no'],'exam score': y_pred})

# %%
new
# Out:
#      Roll No  exam score
# 0   EXA32000   70.910000
# 1   EXA32001   70.825000
# 2   EXA32002   55.740000
# 3   EXA32003   72.510833
# 4   EXA32004   65.116667
# ..       ...         ...
# 95  EXA32095   72.693548
# 96  EXA32096   74.200000
# 97  EXA32097   77.570000
# 98  EXA32098   63.156667
# 99  EXA32099   74.260000
#
# [100 rows x 2 columns]

# %%
new.to_csv(r"C:\Users\SAI SNEHA\Documents\B191333\Hackathon\output_submission.csv")
